# %% [markdown]
# <a href="https://colab.research.google.com/github/fire-long/4J/blob/model4/%EB%AA%A8%EB%8D%B8%EB%A7%814_%EA%B0%9C%EC%84%A0%EC%BD%94%EB%93%9C_%EB%B0%95%EC%A7%84%EC%98%81_huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Package

# %%
import os
import random
from tqdm import tqdm

import pandas as pd
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from transformers import TrainingArguments, Trainer, AutoModelForSequenceClassification, AutoConfig, AutoTokenizer, MarianMTModel, MarianTokenizer
#MarianMTModel, MarianTokenizer 추가

# %% [markdown]
# ### Load Data
# Data가 위치한 PATH에서 Data를 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH =  '/content/drive/MyDrive/JJJJ/model4'

train = pd.read_csv(os.path.join(PATH, 'train_data.csv'), encoding='utf-8')
test = pd.read_csv(os.path.join(PATH, 'test_data.csv'), encoding='utf-8')
train.head(5)
# Out:
#    index                                            premise  \
# 0      0  씨름은 상고시대로부터 전해져 내려오는 남자들의 대표적인 놀이로서, 소년이나 장정들이...
# 1      1  삼성은 자작극을 벌인 2명에게 형사 고소 등의 법적 대응을 검토 중이라고 하였으나,...
# 2      2                    이를 위해 예측적 범죄예방 시스템을 구축하고 고도화한다.
# 3      3  광주광역시가 재개발 정비사업 원주민들에 대한 종합대책을 마련하는 등 원주민 보호에 ...
# 4      4  진정 소비자와 직원들에게 사랑 받는 기업으로 오래 지속되고 싶으면, 이런 상황에서는...
#
#                                 hypothesis          label
# 0                           씨름의 여자들의 놀이이다.  contradiction
# 1                         자작극을 벌인 이는 3명이다.  contradiction
# 2  예측적 범죄예방 시스템 구축하고 고도화하는 것은 목적이 있기 때문이다.     entailment
# 3                        원주민들은 종합대책에 만족했다.        neutral
# 4       이런 상황에서 책임 있는 모습을 보여주는 기업은 아주 드물다.        neutral

# %% [markdown]
# ### 전제, 가설 길이 확인
# Train에 존재하는 Premise(전제), Hypothesis(가설)의 길이를 확인하고 이를 통해 Tokenizer의 max_length 설정이 가능

# %%
max_len = np.max(train['premise'].str.len())
min_len = np.min(train['premise'].str.len())
mean_len = np.mean(train['premise'].str.len())

print('Max Premise Length: ', max_len)
print('Min Premise Length: ', min_len)
print('Mean Premise Lenght: ', mean_len, '\n')

max_len = np.max(train['hypothesis'].str.len())
min_len = np.min(train['hypothesis'].str.len())
mean_len = np.mean(train['hypothesis'].str.len())

print('Max Hypothesis Length: ', max_len)
print('Min Hypothesis Length: ', min_len)
print('Mean Hypothesis Lenght: ', mean_len)
# Out:
# Max Premise Length:  90
# Min Premise Length:  19
# Mean Premise Lenght:  45.406552524201935
#
# Max Hypothesis Length:  103
# Min Hypothesis Length:  5
# Mean Hypothesis Lenght:  24.924433954716378

# %% [markdown]
# ### 간단한 Test Preprocessing
# 전제, 가설에 존재하는 한글 단어가 아닌 다른 단어들은 전부 제거해줍니다.

# %% [markdown]
# .str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]', '')
# - [^ ]: 대괄호 안의 ^ 기호는 not을 의미.
# - ㄱ-ㅎㅏ-ㅣ가-힣 0-9: 한글 자음, 모음, 한글 글자, 영문 대소문자, 숫자, 공백을 의미

# %%
train['premise'] = train['premise'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]', '')
test['premise'] = test['premise'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]", "")
train.head(5)
# Out:
# <ipython-input-5-2d3af709e460>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['premise'] = train['premise'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]', '')
# <ipython-input-5-2d3af709e460>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['premise'] = test['premise'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]", "")
#    index                                            premise  \
# 0      0  씨름은 상고시대로부터 전해져 내려오는 남자들의 대표적인 놀이로서 소년이나 장정들이 ...
# 1      1  삼성은 자작극을 벌인 2명에게 형사 고소 등의 법적 대응을 검토 중이라고 하였으나 ...
# 2      2                     이를 위해 예측적 범죄예방 시스템을 구축하고 고도화한다
# 3      3  광주광역시가 재개발 정비사업 원주민들에 대한 종합대책을 마련하는 등 원주민 보호에 ...
# 4      4  진정 소비자와 직원들에게 사랑 받는 기업으로 오래 지속되고 싶으면 이런 상황에서는 ...
#
#                                 hypothesis          label
# 0                           씨름의 여자들의 놀이이다.  contradiction
# 1                         자작극을 벌인 이는 3명이다.  contradiction
# 2  예측적 범죄예방 시스템 구축하고 고도화하는 것은 목적이 있기 때문이다.     entailment
# 3                        원주민들은 종합대책에 만족했다.        neutral
# 4       이런 상황에서 책임 있는 모습을 보여주는 기업은 아주 드물다.        neutral

# %%
train['hypothesis'] = train['hypothesis'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]', '')
test['hypothesis'] = test['hypothesis'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]", "")
train.head(5)
# Out:
# <ipython-input-6-7d1dabf81269>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['hypothesis'] = train['hypothesis'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]', '')
# <ipython-input-6-7d1dabf81269>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test['hypothesis'] = test['hypothesis'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 0-9]", "")
#    index                                            premise  \
# 0      0  씨름은 상고시대로부터 전해져 내려오는 남자들의 대표적인 놀이로서 소년이나 장정들이 ...
# 1      1  삼성은 자작극을 벌인 2명에게 형사 고소 등의 법적 대응을 검토 중이라고 하였으나 ...
# 2      2                     이를 위해 예측적 범죄예방 시스템을 구축하고 고도화한다
# 3      3  광주광역시가 재개발 정비사업 원주민들에 대한 종합대책을 마련하는 등 원주민 보호에 ...
# 4      4  진정 소비자와 직원들에게 사랑 받는 기업으로 오래 지속되고 싶으면 이런 상황에서는 ...
#
#                                hypothesis          label
# 0                           씨름의 여자들의 놀이이다  contradiction
# 1                         자작극을 벌인 이는 3명이다  contradiction
# 2  예측적 범죄예방 시스템 구축하고 고도화하는 것은 목적이 있기 때문이다     entailment
# 3                        원주민들은 종합대책에 만족했다        neutral
# 4       이런 상황에서 책임 있는 모습을 보여주는 기업은 아주 드물다        neutral

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Download transformers and Import Package

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %% [markdown]
# ### Seed 고정, GPU 설정

# %% [markdown]
# 딥러닝 모델 학습할 때, CPU보다 CUDA 디바이스가 더 빠르고 사용하기 좋음.

# %%
def seed_everything(seed:int = 1004):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
    torch.backends.cudnn.deterministic = True  # type: ignore
    torch.backends.cudnn.benchmark = True  # type: ignore

seed_everything(42)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
#현재 시스템에서 GPU(CUDA)를 사용할 수 있는지 여부를 확인하고, 사용 가능한 경우 CUDA 디바이스를 선택함
# 가능한 경우 "cuda:0"이라는 CUDA 디바이스를 선택하고, 그렇지 않으면 "cpu" 디바이스를 선택함
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### (코드개선) 역번역을 위한 함수
# - 시간과 자원의 문제로 실행은 못함
# - 역변역 및 강화학습 시도

# %%
def backtranslate(sentences, src_lang='ko', target_lang='en'):
    model_name = f'Helsinki-NLP/opus-mt-{src_lang}-{target_lang}'
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)

    translated_sentences = []
    for sentence in tqdm(sentences, desc=f"Translating from {src_lang} to {target_lang}"):
        inputs = tokenizer(sentence, return_tensors="pt", truncation=True)
        outputs = model.generate(**inputs)
        translated_sentence = tokenizer.decode(outputs[0], skip_special_tokens=True)
        translated_sentences.append(translated_sentence)

    return translated_sentences

def augment_data(data, num_backtranslations=3):
    augmented_data = []
    for i in tqdm(range(len(data)), desc="Augmenting data with backtranslations"):
        premise = data['premise'][i]
        hypothesis = data['hypothesis'][i]
        label = data['label'][i]

        # Translate premise and hypothesis to English for backtranslation
        translated_premise = backtranslate([premise])[0]
        translated_hypothesis = backtranslate([hypothesis])[0]

        # Backtranslate to the original language
        backtranslated_premises = backtranslate([translated_premise] * num_backtranslations)
        backtranslated_hypotheses = backtranslate([translated_hypothesis] * num_backtranslations)

        for bt_premise, bt_hypothesis in zip(backtranslated_premises, backtranslated_hypotheses):
            augmented_data.append({
                'premise': bt_premise,
                'hypothesis': bt_hypothesis,
                'label': label
            })

    return augmented_data

# %%
augmented_train_data = augment_data(train, num_backtranslations=3)
augmented_train = pd.DataFrame(augmented_train_data)
train = pd.concat([train, augmented_train], ignore_index=True)
# Out:
# Augmenting data with backtranslations:   0%|          | 0/24998 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/842k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.72M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:13<00:26, 13.31s/it]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:26<00:13, 13.31s/it]
# Translating from ko to en: 100%|██████████| 3/3 [00:40<00:00, 13.34s/it]
# Augmenting data with backtranslations:   7%|▋         | 1639/24998 [7:04:58<183:57:56, 28.35s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.80it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.79it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.49it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.51it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.52it/s]
# Augmenting data with backtranslations:   7%|▋         | 1640/24998 [7:05:14<158:58:16, 24.50s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.54it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.55it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.58it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.57it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.72it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.68it/s]
# Augmenting data with backtranslations:   7%|▋         | 1641/24998 [7:05:28<139:37:23, 21.52s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.88it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.63it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.70it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.76it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.38it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.30it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.29it/s]
# Augmenting data with backtranslations:   7%|▋         | 1642/24998 [7:05:42<124:36:06, 19.21s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.46it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.43it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.44it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:03<00:07,  3.84s/it]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:07<00:03,  3.87s/it]
# Translating from ko to en: 100%|██████████| 3/3 [00:11<00:00,  3.77s/it]
# Augmenting data with backtranslations:   7%|▋         | 1643/24998 [7:06:08<137:22:57, 21.18s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.91it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.76it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.80it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.23it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.30it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.27it/s]
# Augmenting data with backtranslations:   7%|▋         | 1644/24998 [7:06:23<126:05:02, 19.44s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.81it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.79it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.39it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.36it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.37it/s]
# Augmenting data with backtranslations:   7%|▋         | 1645/24998 [7:06:41<122:13:58, 18.84s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.74it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.54it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.54it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.55it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.36it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.39it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.27it/s]
# Augmenting data with backtranslations:   7%|▋         | 1646/24998 [7:06:56<116:02:52, 17.89s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.39it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.83it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.21it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.30it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.27it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.52it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.57it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.56it/s]
# Augmenting data with backtranslations:   7%|▋         | 1647/24998 [7:07:11<110:20:28, 17.01s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.65it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.66it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.67it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.35it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.36it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.35it/s]
# Augmenting data with backtranslations:   7%|▋         | 1648/24998 [7:07:28<110:05:04, 16.97s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.36it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.24it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.25it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.61it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.54it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.49it/s]
# Augmenting data with backtranslations:   7%|▋         | 1649/24998 [7:07:42<103:47:29, 16.00s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.53it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.59it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.59it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.62it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.70it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.74it/s]
# Augmenting data with backtranslations:   7%|▋         | 1650/24998 [7:07:58<103:06:27, 15.90s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.88it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.94it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.91it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.92it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.07it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.04it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.01it/s]
# Augmenting data with backtranslations:   7%|▋         | 1651/24998 [7:08:13<101:37:50, 15.67s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.02it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.55it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.63it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.73it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.03it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.00it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.95it/s]
# Augmenting data with backtranslations:   7%|▋         | 1652/24998 [7:08:27<99:04:37, 15.28s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.93it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.41it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.49it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.44it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.44it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.40it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.43it/s]
# Augmenting data with backtranslations:   7%|▋         | 1653/24998 [7:08:41<96:21:27, 14.86s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.10it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.11it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.11it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.60it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.57it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.54it/s]
# Augmenting data with backtranslations:   7%|▋         | 1654/24998 [7:08:58<100:00:09, 15.42s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.38it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.36it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.34it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.43it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.85it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.83it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.82it/s]
# Augmenting data with backtranslations:   7%|▋         | 1655/24998 [7:09:14<102:26:54, 15.80s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.12it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.23it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.89it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.85it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.87it/s]
# Augmenting data with backtranslations:   7%|▋         | 1656/24998 [7:09:29<100:51:46, 15.56s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.60it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.62it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.65it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.26it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.27it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.30it/s]
# Augmenting data with backtranslations:   7%|▋         | 1657/24998 [7:09:46<102:13:57, 15.77s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.63it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.72it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.54it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.61it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.22it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.16it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.19it/s]
# Augmenting data with backtranslations:   7%|▋         | 1658/24998 [7:10:02<102:51:10, 15.86s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.95it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.96it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.89it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.96it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.25it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.25it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.25it/s]
# Augmenting data with backtranslations:   7%|▋         | 1659/24998 [7:10:16<99:22:30, 15.33s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.80it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.73it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.10it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.02it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.95it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.88it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.00it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.91it/s]
# Augmenting data with backtranslations:   7%|▋         | 1660/24998 [7:10:30<97:43:22, 15.07s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.35it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.31it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.29it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.09it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.04it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.02it/s]
# Augmenting data with backtranslations:   7%|▋         | 1661/24998 [7:10:47<101:22:40, 15.64s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.18it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.27it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.27it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.51it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.49it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s]
# Augmenting data with backtranslations:   7%|▋         | 1662/24998 [7:11:02<99:31:16, 15.35s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.29it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.27it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.38it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.46it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.35it/s]
# Augmenting data with backtranslations:   7%|▋         | 1663/24998 [7:11:18<101:14:52, 15.62s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.66it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.69it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.60it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.19it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.14it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.20it/s]
# Augmenting data with backtranslations:   7%|▋         | 1664/24998 [7:11:33<99:59:29, 15.43s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.17it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.21it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.16it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.52it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.59it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.59it/s]
# Augmenting data with backtranslations:   7%|▋         | 1665/24998 [7:11:48<97:49:57, 15.09s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.51it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.22it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.21it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.22it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.79it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.80it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# Augmenting data with backtranslations:   7%|▋         | 1666/24998 [7:12:05<101:27:58, 15.66s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.86it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.07it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.03it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.03it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.85it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.85it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# Augmenting data with backtranslations:   7%|▋         | 1667/24998 [7:12:22<104:56:27, 16.19s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.01it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.26it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.37it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.35it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.16it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.16it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.22it/s]
# Augmenting data with backtranslations:   7%|▋         | 1668/24998 [7:12:37<101:56:55, 15.73s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.56it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.38it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.35it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.31it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.79it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.74it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.68it/s]
# Augmenting data with backtranslations:   7%|▋         | 1669/24998 [7:12:51<100:15:27, 15.47s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.13it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.12it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.80it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.73it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.72it/s]
# Augmenting data with backtranslations:   7%|▋         | 1670/24998 [7:13:08<102:06:21, 15.76s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  4.02it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.03it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  2.00it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.01it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.62it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.41it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.47it/s]
# Augmenting data with backtranslations:   7%|▋         | 1671/24998 [7:13:22<99:31:05, 15.36s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.60it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.61it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.64it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.25it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.09it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.92it/s]
# Augmenting data with backtranslations:   7%|▋         | 1672/24998 [7:13:36<97:05:33, 14.98s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.72it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.89it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.88it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.66it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.75it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# Augmenting data with backtranslations:   7%|▋         | 1673/24998 [7:13:53<99:46:51, 15.40s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.31it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.47it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.45it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.24it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.37it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.39it/s]
# Augmenting data with backtranslations:   7%|▋         | 1674/24998 [7:14:09<101:24:06, 15.65s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.37it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.36it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.36it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.28it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.33it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.06it/s]
# Augmenting data with backtranslations:   7%|▋         | 1675/24998 [7:14:26<103:14:05, 15.93s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.81it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.86it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.72it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.75it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.14it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.13it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.12it/s]
# Augmenting data with backtranslations:   7%|▋         | 1676/24998 [7:14:40<100:54:56, 15.58s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.10it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.50it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.56it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.98it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.94it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.88it/s]
# Augmenting data with backtranslations:   7%|▋         | 1677/24998 [7:14:54<98:02:39, 15.13s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.00it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.25it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.22it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.24it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.56it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.45it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s]
# Augmenting data with backtranslations:   7%|▋         | 1678/24998 [7:15:10<98:32:21, 15.21s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.32it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.79it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.76it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.73it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.92it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.93it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.01it/s]
# Augmenting data with backtranslations:   7%|▋         | 1679/24998 [7:15:26<99:23:26, 15.34s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.16it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.05it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.95it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.97it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.09it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.13it/s]
# Augmenting data with backtranslations:   7%|▋         | 1680/24998 [7:15:39<95:56:15, 14.81s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.59it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.61it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.60it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.67it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.64it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.67it/s]
# Augmenting data with backtranslations:   7%|▋         | 1681/24998 [7:15:54<96:57:58, 14.97s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.64it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.69it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.71it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.55it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.66it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.67it/s]
# Augmenting data with backtranslations:   7%|▋         | 1682/24998 [7:16:09<95:37:37, 14.76s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.04it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.52it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.92it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.90it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.88it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.13it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.19it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s]
# Augmenting data with backtranslations:   7%|▋         | 1683/24998 [7:16:23<95:17:46, 14.71s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.08it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.91it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.92it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.77it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.66it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.73it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.68it/s]
# Augmenting data with backtranslations:   7%|▋         | 1684/24998 [7:16:38<94:51:45, 14.65s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.72it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.04it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.75it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.79it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.97it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.92it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.93it/s]
# Augmenting data with backtranslations:   7%|▋         | 1685/24998 [7:16:54<97:24:53, 15.04s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.54it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.96it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.88it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.87it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.88it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.84it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# Augmenting data with backtranslations:   7%|▋         | 1686/24998 [7:17:09<97:28:51, 15.05s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.21it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.21it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.13it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.91it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  5.00it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.91it/s]
# Augmenting data with backtranslations:   7%|▋         | 1687/24998 [7:17:25<98:49:26, 15.26s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.17it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.06it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.14it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.15it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.61it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.81it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.71it/s]
# Augmenting data with backtranslations:   7%|▋         | 1688/24998 [7:17:38<95:25:22, 14.74s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.30it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.29it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.29it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.92it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.88it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.95it/s]
# Augmenting data with backtranslations:   8%|▊         | 1935/24998 [8:23:04<114:44:58, 17.91s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.41it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.81it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.64it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.80it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.78it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.70it/s]
# Augmenting data with backtranslations:   8%|▊         | 1936/24998 [8:23:18<106:44:48, 16.66s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.41it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.38it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.35it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.36it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.65it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.69it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.67it/s]
# Augmenting data with backtranslations:   8%|▊         | 1937/24998 [8:23:33<104:04:47, 16.25s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.38it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.38it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.39it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.24it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.19it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.12it/s]
# Augmenting data with backtranslations:   8%|▊         | 1938/24998 [8:23:49<104:26:19, 16.30s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.52it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.54it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.46it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.27it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.37it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.36it/s]
# Augmenting data with backtranslations:   8%|▊         | 1939/24998 [8:24:12<115:47:26, 18.08s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.87it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  4.96it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.08it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.87it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.83it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.63it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.55it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.52it/s]
# Augmenting data with backtranslations:   8%|▊         | 1940/24998 [8:24:25<106:33:48, 16.64s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  2.00it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.98it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.99it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.99it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.98it/s]
# Augmenting data with backtranslations:   8%|▊         | 1941/24998 [8:24:40<104:10:28, 16.27s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.79it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.77it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.76it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.57it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.67it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.65it/s]
# Augmenting data with backtranslations:   8%|▊         | 1942/24998 [8:24:56<102:16:06, 15.97s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.61it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.66it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.11it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.03it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.03it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.45it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.48it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.41it/s]
# Augmenting data with backtranslations:   8%|▊         | 1943/24998 [8:25:09<97:58:18, 15.30s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.77it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.76it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.70it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.67it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.68it/s]
# Augmenting data with backtranslations:   8%|▊         | 1944/24998 [8:25:25<97:53:02, 15.29s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:01<00:02,  1.03s/it]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.12it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.14it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.04it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.12it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.11it/s]
# Augmenting data with backtranslations:   8%|▊         | 1945/24998 [8:25:40<99:08:02, 15.48s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.56it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.35it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  3.82it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  3.81it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.32it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.48it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.33it/s]
# Augmenting data with backtranslations:   8%|▊         | 1946/24998 [8:25:54<95:10:33, 14.86s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  2.74it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.22it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.80it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.81it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.83it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.83it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.05it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.11it/s]
# Augmenting data with backtranslations:   8%|▊         | 1947/24998 [8:26:15<107:34:33, 16.80s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  2.56it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.58it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  4.30it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  4.19it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:00<00:00,  4.22it/s]
# Augmenting data with backtranslations:   8%|▊         | 1948/24998 [8:26:29<102:00:04, 15.93s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.33it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.34it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.34it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.20it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.25it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.27it/s]
# Augmenting data with backtranslations:   8%|▊         | 1949/24998 [8:26:47<105:54:11, 16.54s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.25it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.24it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:01,  1.57it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:01<00:00,  1.57it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  1.58it/s]
# Augmenting data with backtranslations:   8%|▊         | 1950/24998 [8:27:04<107:09:16, 16.74s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:02<00:00,  2.62s/it]
#
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]
# Translating from ko to en: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:06<00:12,  6.17s/it]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:12<00:06,  6.06s/it]
# Translating from ko to en: 100%|██████████| 3/3 [00:18<00:00,  6.10s/it]
#
# Translating from ko to en:   0%|          | 0/3 [00:00<?, ?it/s]
# Translating from ko to en:  33%|███▎      | 1/3 [00:00<00:00,  3.02it/s]
# Translating from ko to en:  67%|██████▋   | 2/3 [00:00<00:00,  2.92it/s]
# Translating from ko to en: 100%|██████████| 3/3 [00:01<00:00,  2.87it/s]
# Augmenting data with backtranslations:   8%|▊         | 1951/24998 [8:27:38<139:29:25, 21.79s/it]
# Translating from ko to en:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Load Tokenizer, Model
# Hugging Face Hub에 존재하는 Pretrained Tokenizer와 Model 및 Model Config를 불러옵니다.
#
# 이 때, Classification은 num_labels가 2로 Default되어있기 때문에 Model Config의 Parameter를 변경해줍니다.

# %% [markdown]
# "klue/roberta-large"와 "klue" 모델 : 모두 KcBERT(Korean commonsense pre-trained BERT) 모델을 기반
# - "klue/roberta-large"는 "klue" 모델보다 더 큰 사이즈의 모델
# - klue는 데이터셋도 제공하므로, 표현에 혼동하지 않기!

# %%
#klue/roberta-large 모델을 불러와서 출력
MODEL_NAME = 'klue/roberta-large'

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)#해당 모델의 tokenizer를 불러옴

#해당 모델의 설정 정보를 불러와서 라벨 수를 3으로 변경
config = AutoConfig.from_pretrained(MODEL_NAME)
config.num_labels = 3

#위에서 설정한 tokenizer와 설정 정보를 이용하여 모델을 불러옴
#AutoModelForSequenceClassification 클래스의 객체를 생성할 때, model() 함수가 생성됨.
#해당 함수가 호출될 때, 입력으로 데이터를 전달하면 내부적으로 forward() 함수가 호출되어
#모델이 입력데이터를 처리하고 출력값을 반환함.
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, config=config)

#모델과 설정 정보 출력
print(model)
print(config)

# %% [markdown]
# ### Tokenizing
# Train Data를 Train과 Validation Dataset으로 나누고 각각 데이터를 Tokenizer를 통해 Tokenizing을 합니다.
#
# Tokenizer에 들어가는 문장은 전제와 가설을 Concat한 문장이 됩니다.

# %%
train_dataset, eval_dataset = train_test_split(train, test_size=0.2, shuffle=True, stratify=train['label'])
#훈련셋과 평가셋으로 나눔
#stratify=train['label']:클래스별로 데이터를 층을 내 샘플링하여 골고루 데이터를 추출함.


# premise와 hypothesis 문장 쌍을 토큰화해서 tokenized_train과 tokenized_eval 데이터셋 생성
'''
max_length을 256으로 설정하는 이유는,
- 256이 대부분의 NLP 모델에서 사용되는 토큰 최대 길이이기 때문임.
- 패딩을 쉽게 처리하기 위해서기도 함.
  (최대길이보다 짧은 문장은 나머지 부분을 패딩토큰으로 채워줘야하는데,
  2의 제곱수로 설정하면 이 작업이 더 효율적으로 처리됨.)
'''
'''
    padding : 모델의 입력 데이터를 일정 길이로 맞추고자 짧은 문장에 부족한 길이를 0으로 채움.
              즉, 패딩 토큰을 추가
    truncation : padding과 목적은 동일하나 긴 문장을 잘라내는 작업만을 말함.
    add_special_tokens : 특별한 의미를 가진 토큰을 입력 데이터에 추가하는 작업
      - [CLS] : 문장의 시작을 나타냄
      - [SEP] : 문장 간 구분 역할
      특수 토큰은 모델학습에 필수적이고, 입력데이터의 양쪽 끝에 추가됨.
      RoBERTa 모델에서는 <s> 토큰을 문장의 시작을 알리는 특별한 토큰으로 사용
'''
tokenized_train = tokenizer(
    list(train_dataset['premise']),
    list(train_dataset['hypothesis']),
    return_tensors="pt", #PyTorch Tensor를 반환하게 함
    max_length=256, # Max_Length = 190
    padding=True,
    truncation=True,
    add_special_tokens=True
)

tokenized_eval = tokenizer(
    list(eval_dataset['premise']),
    list(eval_dataset['hypothesis']),
    return_tensors="pt",
    max_length=256,
    padding=True,
    truncation=True,
    add_special_tokens=True
)

#tokenizer 후, 0번째 인덱스의 데이터의 input_ids를 출력하고, 이를 다시 decode해서 본 문장으로 변환함.
#tokenization 과정에서 어떤 변화가 일어났는지 확인 가능.
'''
tokenization에선 문장을 subword로 나누고, 각 subword를 숫자로 변환하는 작업이 수행됨.
이때, input_ids는 각 subword를 대응하는 숫자 id로 변환된 결과를 나타냄.
'''
print(tokenized_train['input_ids'][0])
#첫 번째 데이터의 subword들을 숫자 id로 변환한 결과를 리스트 형태로 담음. 즉, tokenization 이후의 결과물
print(tokenizer.decode(tokenized_train['input_ids'][0]))
#이를 decode 함수를 사용하여 다시 원래의 문장으로 변환하면, subword에서 숫자 id로 변환한 과정에서 생긴 변화를 다시 원래 문장으로 돌릴 수 있음

# %% [markdown]
# PyTorch의 Dataset 클래스를 상속하여 새로운 데이터셋 클래스인 BERTDataset을 정의

# %%
class BERTDataset(torch.utils.data.Dataset):
    def __init__(self, pair_dataset, label):
      #초기화
        self.pair_dataset = pair_dataset
        self.label = label

    def __getitem__(self, idx):
      #모델의 입력 데이터를 처리하는 데 필요한 method
      #인덱스를 입력으로 받아 데이터셋에서 해당 인덱스에 해당하는 샘플을 반환
        item = {key: val[idx].clone().detach() for key, val in self.pair_dataset.items()}
        #pair_dataset : 입력문장 쌍을 포함하는 dict
        #item은 pair_dataset에서 해당 인덱스에 해당하는 문장쌍을 가져와서 'clone().detach()'로 복사함
        item['label'] = torch.tensor(self.label[idx])
        #item['labl']에 해당 인덱스의 레이블값 저장
        return item

    def __len__(self):
      #데이터셋의 크기를 반환하는 method
        return len(self.label)

# %%
def label_to_num(label):
  #label 컬럼에 해당하는 값을 인자로 받아서 레이블을 정수로 바꿔주는 함수
    label_dict = {"entailment": 0, "contradiction": 1, "neutral": 2, "answer": 3}
    num_label = []

    for v in label:
        num_label.append(label_dict[v])

    return num_label


train_label = label_to_num(train_dataset['label'].values)
eval_label = label_to_num(eval_dataset['label'].values)

# %%
#위에서 만든 BERTDataset 함수로 train_dataset과 eval_dataset을 만들었음.
train_dataset = BERTDataset(tokenized_train, train_label)
eval_dataset = BERTDataset(tokenized_eval, eval_label)

#__len__, __getitem__ 메소드 사용

#문장 쌍의 개수를 출력
print(train_dataset.__len__())

#train_dataset에서 19997번째 문장쌍을 출력함
print(train_dataset.__getitem__(19997))


#해당 데이터의 input_ids를 tokenization 이전 상태로 디코딩하여 출력
#디코딩된 문장을 보면 [CLS]와 [SEP] 토큰이 추가되어 있으며, [PAD] 토큰이 추가되어 길이가 256이 되도록 padding됨
print(tokenizer.decode(train_dataset.__getitem__(19997)['input_ids']))

# %%
def compute_metrics(pred):
  """ validation을 위한 metrics function """
  '''
  Hugging Face의 Transformers 라이브러리에서는 학습 시 validation을 수행할 때 Trainer 클래스를 사용함
  해당 클래스에선 compute_metrics 함수를 인자로 받아서 validation set의 예측결과와 정답값을 이용해 평가 지표를 계산함

  -> 함수의 입력값인 pred:
     'Trainer' 클래스에서 검증 셋의 batch별로 inference(학습된 모델이 파라미터를
     이용해 새로운 입력 데이터에 대한 예측을 수행)한 결과를 모은 객체

     (* batch 단위로 입력 데이터를 묶어서 연산을 수행해 속도를 향상시킴)
  '''
  labels = pred.label_ids #정답 라벨의 id값들
  preds = pred.predictions.argmax(-1) #예측 결과의 logit값을 담은 tensor
  #logit : 모델의 출력값 중 하나. 클래스 분류 문제에서 클래스의 개수와 같은 차원으로 출력됨
         #값이 클수록 해당클래스일 확률이 높은 것
  #predictions.argmax(-1): predictions의 마지막 차원에 따라 가장 큰 값을 지닌 인덱스를 반환함.
  #즉, 모델이 분류하려는 클래스 중에서 가장 높은 확률을 가지는 클래스의 인덱스를 반환
         #argmax():주어진 축(axis)에 따라 가장 큰 값을 가진 인덱스를 반환하는 함수
                  #파이토치에선 주어진 텐서의 가장 큰 값을 가진 인덱스르 반환함
  probs = pred.predictions

  # calculate accuracy using sklearn's function
  acc = accuracy_score(labels, preds) # 리더보드 평가에는 포함되지 않습니다.
  # acc : labels와 preds의 값을 비교해 같은 경우의 수를 전체 케이스 수로 나눈 값
  return {
      'accuracy': acc,
  }

# %%
#Trainer 클래스를 이용해 모델 학습을 위한 설정을 진행함.
#이전까지의 작업은 대체로 Trainer 사용을 위해 전처리 작업이 진행된 것

#학습에 필요한 arguments 설정
training_ars = TrainingArguments(
    output_dir='./result', #모델 체크포인트 및 로그 저장 디렉토리 경로
    num_train_epochs=7, #epochs
    per_device_train_batch_size=32, #batch size
    save_total_limit=5, #최대로 저장할 체크포인트 개수
    save_steps=500, #일정한 스텝마다 체크포인트 저장
    evaluation_strategy='steps',#evaluation을 언제 수행할지 결정. 여기선 일정 step마다 진행
    eval_steps = 500,#일정한 스텝마다 evaluation 수행
    load_best_model_at_end = True,#학습 종료 후 최고 성능을 보인 모델 불러오기 여부
)

#모델 학습을 실행하는 Trainer.
#데이터를 per_device_train_batch_size 개수만큼씩 잘라서 학습
trainer = Trainer(
    model=model,
    args=training_ars,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# %%
trainer.train() #학습을 시작하는 method
model.save_pretrained('./result/best_model') #최고 성능 모델을 해당 경로에 저장하는 method
#모델의 가중치(weight)와 tokenizer 정보도 함께 저장

# %%
#GPU가 사용 가능하면 GPU를, 아니면 CPU를 사용하도록 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

#로버타(RoBERTa) 모델의 토크나이저명을 설정하고, 이전에 학습해준 ROBERTa 모델의 토크나이저를 불러옴
Tokenizer_NAME = "klue/roberta-large"
tokenizer = AutoTokenizer.from_pretrained(Tokenizer_NAME)

#이전에 학습해준 ROBERTa의 경로를 지정하여 모델을 불러주고
MODEL_NAME = './result/checkpoint-4000'
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)

#해당 모델의 tokenizer와 임베딩 크기가 일치하도록 조정해줌
model.resize_token_embeddings(tokenizer.vocab_size)

#모델의 GPU나 CPU를 옮기는 코드
model.to(device)


print(tokenizer)

# %%
#test 데이터셋의 레이블 데이터를 수치화
test_label = label_to_num(test['label'].values)

#tokenizer로 test 데이터셋을 토큰화하고 tokenized_test에 저장함.
tokenized_test = tokenizer(
    list(test['premise']),
    list(test['hypothesis']),
    return_tensors="pt", #PyTorch tensor 형식으로 반환됨
    max_length=128,#토큰화된 데이터의 최대 길이
    padding=True,
    truncation=True,
    add_special_tokens=True
)
#tokenized_test와 test_label을 사용하여 test_dataset을 생성
test_dataset = BERTDataset(tokenized_test, test_label)

#__len__과 __getitem__ 메서드를 통해 데이터셋의 크기와 데이터를 조회
print(test_dataset.__len__())
print(test_dataset.__getitem__(1665)) #토큰화된 데이터를 이용하여 딕셔너리 형태의 1665번째 쌍 아이템을 반환
print(tokenizer.decode(test_dataset.__getitem__(6)['input_ids']))#토큰화된 데이터를 다시 텍스트 형식으로 변환

# %% [markdown]
#  test 데이터셋을 이용해 예측 결과를 도출하는 코드

# %%
#. DataLoader를 이용하여 배치 단위로 데이터를 가져와 모델에 입력으로 넣음
dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

model.eval() #모델을 evaluation mode로 설정
output_pred = []
output_prob = []

#모델의 출력 결과를 이용해 예측한 결과와 확률값을 추출
#enumerate으로 DataLoader에서 하나씩 batch 데이터를 가져옴
for i, data in enumerate(tqdm(dataloader)):
    with torch.no_grad():# with torch.no_grad()를 사용하여 autograd 역전파를 수행하지 않음
     #각 batch의 input_ids, attention_mask, token_type_ids를 GPU로 이동시킴
        outputs = model(
            input_ids=data['input_ids'].to(device),
            attention_mask=data['attention_mask'].to(device),
            token_type_ids=data['token_type_ids'].to(device)
        )
    '''
    forward 함수를 호출함
    이유 : DataLoader는 입력 데이터를 모델의 forward 함수에 넣고 예측값을 반환함
    DataLoader의 for문에서 모델에 입력 데이터를 전달하는 부분이 forward 함수를 호출하는 부분
    evaluation 모드로 설정되어 있어서,
    forward 함수를 호출할 때 모델이 가지고 있는 파라미터들이 업데이트되지 않음
    '''
    logits = outputs[0]
    #logits를 softmax해서 확률값으로 변환하고 prob에 저장
    prob = F.softmax(logits, dim=-1).detach().cpu().numpy()

    #logits도 CPU로 이동시키고 numpy() method 호출해서 result에 저장함.
    logits = logits.detach().cpu().numpy()
    result = np.argmax(logits, axis=-1)

    # output_pred와 output_prob에 결과를 저장
    output_pred.append(result)
    output_prob.append(prob)

#pred_answer와 output_prob에 합쳐진 리스트를 저장
pred_answer, output_prob = np.concatenate(output_pred).tolist(), np.concatenate(output_prob, axis=0).tolist()
print(pred_answer)

# %%
#숫자로 된 라벨을 해당하는 문자열 라벨로 다시 바꿔주는 함수
def num_to_label(label):
    label_dict = {0: "entailment", 1: "contradiction", 2: "neutral"}
    str_label = []

    for i, v in enumerate(label):
        str_label.append([i,label_dict[v]])

    return str_label

answer = num_to_label(pred_answer)
print(answer)

# %%
df = pd.DataFrame(answer, columns=['index', 'label'])

df.to_csv('./result/submission.csv', index=False)

print(df)
